# %%
# generic imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# notebook settings
# %config IPCompleter.greedy=True
# %load_ext autoreload
# %autoreload 2 
# precision and plot settings
num_precision = 3
np.set_printoptions(precision=num_precision, suppress=True)
pd.set_option('display.float_format', lambda x: f'{x:,.{num_precision}f}')
pd.set_option("display.precision", num_precision)
pd.set_option('display.max_columns', None)

plt.style.use('tableau-colorblind10')
plt.rcParams['figure.figsize'] = [10, 6]
plt.rcParams['font.size'] = 16
plt.rcParams['legend.fontsize'] = 'large'
plt.rcParams['figure.titlesize'] = 'medium'
plt.rcParams['lines.linewidth'] = 2

# %%
# setup dir and import helper functions
import sys, os
sys.path.append(os.path.join(os.path.dirname(sys.path[0]),'src'))
import helper_funcs as my_funcs

# %%
# subset the new data we have to see what the numbers and class balances look like
USdata_with_est_campgrounds = pd.read_csv('../data/USdata_est_campgrounds_zip_states_combined_cleaned.csv')
USdata_with_est_campgrounds.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-03ca7743deb7> in <module>
#       1 # subset the new data we have to see what the numbers and class balances look like
#       2 USdata_with_est_campgrounds = pd.read_csv('../data/USdata_est_campgrounds_zip_states_combined_cleaned.csv')
# ----> 3 USdata_with_est_campgrounds.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1, inplace=True)
#
# /usr/local/anaconda3/envs/tf_py377/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /usr/local/anaconda3/envs/tf_py377/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# /usr/local/anaconda3/envs/tf_py377/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# /usr/local/anaconda3/envs/tf_py377/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0.1'] not found in axis"

# %%
USdata_with_est_campgrounds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12412 entries, 0 to 12411
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Location                   2241 non-null   object
#  1   Name                       12412 non-null  object
#  2   Category                   12412 non-null  object
#  3   Description                12411 non-null  object
#  4   Latitude                   12412 non-null  float64
#  5   Longitude                  12412 non-null  float64
#  6   Altitude                   12103 non-null  float64
#  7   Date verified              12412 non-null  object
#  8   Open                       12412 non-null  object
#  9   Electricity                11609 non-null  object
#  10  Wifi                       11609 non-null  object
#  11  Kitchen                    11609 non-null  object
#  12  Parking                    0 non-null      float64
#  13  Restaurant                 11609 non-null  object
#  14  Showers                    11873 non-null  object
#  15  Water                      11609 non-null  object
#  16  Toilets                    11609 non-null  object
#  17  Big rig friendly           11609 non-null  object
#  18  Tent friendly              11609 non-null  object
#  19  Pet friendly               11609 non-null  object
#  20  Sanitation dump station    3740 non-null   object
#  21  Outdoor gear               0 non-null      float64
#  22  Groceries                  0 non-null      float64
#  23  Artesian goods             0 non-null      float64
#  24  Bakery                     0 non-null      float64
#  25  Rarity in this area        0 non-null      float64
#  26  Repairs vehicles           0 non-null      float64
#  27  Repairs motorcycles        0 non-null      float64
#  28  Repairs bicycles           0 non-null      float64
#  29  Sells parts                0 non-null      float64
#  30  Recycles batteries         21 non-null     object
#  31  Recycles oil               21 non-null     object
#  32  Bio fuel                   21 non-null     object
#  33  Electric vehicle charging  21 non-null     object
#  34  Composting sawdust         21 non-null     object
#  35  Recycling center           21 non-null     object
#  36  zip_code                   9625 non-null   object
#  37  State                      11866 non-null  object
# dtypes: float64(13), object(25)
# memory usage: 3.6+ MB

# %%
# names = ['CO', 'CA', 'AZ', 'OR', 'UT', 'WA']
names = ['TX', 'FL', 'AK', 'MT', 'NM', 'ID', 'WY', 'NV', 'NY']

# %%
USdata_with_est_campgrounds.groupby('State').agg('count')['Description'].sort_values(ascending=False).head(20)
# Out:
# State
# CA    1698
# AZ     886
# OR     729
# CO     707
# WA     692
# UT     651
# TX     576
# FL     465
# AK     452
# MT     446
# NM     426
# ID     383
# WY     298
# NV     285
# NY     197
# VA     161
# NC     157
# TN     152
# MI     144
# SD     144
# Name: Description, dtype: int64

# %%
USdata_with_est_campgrounds_other_states = USdata_with_est_campgrounds[USdata_with_est_campgrounds['State'].isin(names)].copy()

# %%
USdata_with_est_campgrounds_other_states.groupby('State').agg('count')['Description'].sort_values(ascending=False).head(20)
# Out:
# State
# TX    576
# FL    465
# AK    452
# MT    446
# NM    426
# ID    383
# WY    298
# NV    285
# NY    197
# Name: Description, dtype: int64

# %%
USdata_with_est_campgrounds_other_states.head()
# Out:
#                                              Location  \
# 2                Glenn Hwy, Glennallen, AK 99588, USA
# 15  12878 East Rebarchek Avenue, Palmer, AK 99645,...
# 16             Unnamed Road, Helmville, MT 59843, USA
# 26                300 Sierra Ln, Verdi, NV 89439, USA
# 30                      NM-9, Columbus, NM 88029, USA
#
#                                     Name                Category  \
# 2   Tolsona River RV Park and Campground  Established Campground
# 15              Palmer State Fairgrounds  Established Campground
# 16                           Browns Lake  Established Campground
# 26                         Gold Ranch RV  Established Campground
# 30               Pancho Villa State Park  Established Campground
#
#                                           Description  Latitude  Longitude  \
# 2   An old standby for us.  Multiple sites for lar...   62.0954  -145.9805
# 15                  Gated fairgrounds, full hook ups    61.5780  -149.1368
# 16  Located on Browns lake. Sate camp site with fe...   46.9514  -113.0107
# 26  Best little RV park in the Reno/Sparks area. C...   39.5017  -120.0004
# 30  A surprisingly nice and inexpensive campground...   31.8270  -107.6429
#
#      Altitude            Date verified Open     Electricity           Wifi  \
# 2      0.0000  2016-05-27 11:38:27 UTC  Yes         Unknown        Unknown
# 15    61.7309  2014-09-04 17:21:15 UTC  Yes  Yes - At Sites  Yes - Average
# 16        nan  2014-08-18 00:00:00 UTC  Yes              No             No
# 26 1,531.1493  2018-02-18 12:15:32 UTC  Yes  Yes - At Sites        Unknown
# 30 1,229.0000  2020-03-03 00:00:00 UTC  Yes  Yes - At Sites             No
#
#     Kitchen  Parking Restaurant  Showers           Water        Toilets  \
# 2   Unknown      nan    Unknown  Unknown         Unknown        Unknown
# 15       No      nan         No       No         Potable  Running Water
# 16       No      nan         No       No  Natural Source    Pit Toilets
# 26  Unknown      nan        Yes  Unknown             Yes        Unknown
# 30       No      nan         No      Hot         Potable  Running Water
#
#    Big rig friendly Tent friendly Pet friendly Sanitation dump station  \
# 2           Unknown       Unknown      Unknown                 Unknown
# 15              Yes            No           No                 Unknown
# 16              Yes           Yes          Yes                 Unknown
# 26          Unknown       Unknown      Unknown                 Unknown
# 30              Yes           Yes          Yes                 Unknown
#
#     Outdoor gear  Groceries  Artesian goods  Bakery  Rarity in this area  \
# 2            nan        nan             nan     nan                  nan
# 15           nan        nan             nan     nan                  nan
# 16           nan        nan             nan     nan                  nan
# 26           nan        nan             nan     nan                  nan
# 30           nan        nan             nan     nan                  nan
#
#     Repairs vehicles  Repairs motorcycles  Repairs bicycles  Sells parts  \
# 2                nan                  nan               nan          nan
# 15               nan                  nan               nan          nan
# 16               nan                  nan               nan          nan
# 26               nan                  nan               nan          nan
# 30               nan                  nan               nan          nan
#
#    Recycles batteries Recycles oil Bio fuel Electric vehicle charging  \
# 2                 NaN          NaN      NaN                       NaN
# 15                NaN          NaN      NaN                       NaN
# 16                NaN          NaN      NaN                       NaN
# 26                NaN          NaN      NaN                       NaN
# 30                NaN          NaN      NaN                       NaN
#
#    Composting sawdust Recycling center zip_code State
# 2                 NaN              NaN      NaN    AK
# 15                NaN              NaN      NaN    AK
# 16                NaN              NaN      NaN    MT
# 26                NaN              NaN      NaN    NV
# 30                NaN              NaN      NaN    NM

# %%
for_summary = USdata_with_est_campgrounds_other_states[['State', 'Category', 'Description']]

# %%
counts = for_summary.groupby(['State','Category']).agg('count').reset_index()

# %%
counts
# Out:
#    State                Category  Description
# 0     AK  Established Campground          136
# 1     AK       Informal Campsite           65
# 2     AK                 Showers           13
# 3     AK                   Water           22
# 4     AK            Wild Camping          216
# 5     FL  Established Campground          179
# 6     FL       Informal Campsite          148
# 7     FL      Short-term Parking            4
# 8     FL                 Showers           11
# 9     FL                   Water           18
# 10    FL            Wild Camping          105
# 11    ID  Established Campground          119
# 12    ID       Informal Campsite           84
# 13    ID                 Showers            4
# 14    ID                   Water           20
# 15    ID            Wild Camping          156
# 16    MT            Eco-Friendly            1
# 17    MT  Established Campground          187
# 18    MT       Informal Campsite           82
# 19    MT                 Showers            9
# 20    MT                   Water           15
# 21    MT            Wild Camping          152
# 22    NM            Eco-Friendly            2
# 23    NM  Established Campground          127
# 24    NM       Informal Campsite           90
# 25    NM      Short-term Parking            1
# 26    NM                 Showers            5
# 27    NM                   Water           21
# 28    NM            Wild Camping          180
# 29    NV  Established Campground           68
# 30    NV       Informal Campsite           70
# 31    NV      Short-term Parking            2
# 32    NV                 Showers            9
# 33    NV                   Water           12
# 34    NV            Wild Camping          124
# 35    NY  Established Campground           82
# 36    NY       Informal Campsite           54
# 37    NY                 Showers            2
# 38    NY                   Water            4
# 39    NY            Wild Camping           55
# 40    TX  Established Campground          245
# 41    TX       Informal Campsite          195
# 42    TX                 Showers            6
# 43    TX                   Water           24
# 44    TX            Wild Camping          106
# 45    WY  Established Campground           92
# 46    WY       Informal Campsite           35
# 47    WY                 Showers            8
# 48    WY                   Water           16
# 49    WY            Wild Camping          147

# %%
counts['%'] = round(counts['Description'].div(counts.groupby('State')['Description'].transform('sum'))*100, 2)

# %%
counts
# Out:
#    State                Category  Description       %
# 0     AK  Established Campground          136 30.0900
# 1     AK       Informal Campsite           65 14.3800
# 2     AK                 Showers           13  2.8800
# 3     AK                   Water           22  4.8700
# 4     AK            Wild Camping          216 47.7900
# 5     FL  Established Campground          179 38.4900
# 6     FL       Informal Campsite          148 31.8300
# 7     FL      Short-term Parking            4  0.8600
# 8     FL                 Showers           11  2.3700
# 9     FL                   Water           18  3.8700
# 10    FL            Wild Camping          105 22.5800
# 11    ID  Established Campground          119 31.0700
# 12    ID       Informal Campsite           84 21.9300
# 13    ID                 Showers            4  1.0400
# 14    ID                   Water           20  5.2200
# 15    ID            Wild Camping          156 40.7300
# 16    MT            Eco-Friendly            1  0.2200
# 17    MT  Established Campground          187 41.9300
# 18    MT       Informal Campsite           82 18.3900
# 19    MT                 Showers            9  2.0200
# 20    MT                   Water           15  3.3600
# 21    MT            Wild Camping          152 34.0800
# 22    NM            Eco-Friendly            2  0.4700
# 23    NM  Established Campground          127 29.8100
# 24    NM       Informal Campsite           90 21.1300
# 25    NM      Short-term Parking            1  0.2300
# 26    NM                 Showers            5  1.1700
# 27    NM                   Water           21  4.9300
# 28    NM            Wild Camping          180 42.2500
# 29    NV  Established Campground           68 23.8600
# 30    NV       Informal Campsite           70 24.5600
# 31    NV      Short-term Parking            2  0.7000
# 32    NV                 Showers            9  3.1600
# 33    NV                   Water           12  4.2100
# 34    NV            Wild Camping          124 43.5100
# 35    NY  Established Campground           82 41.6200
# 36    NY       Informal Campsite           54 27.4100
# 37    NY                 Showers            2  1.0200
# 38    NY                   Water            4  2.0300
# 39    NY            Wild Camping           55 27.9200
# 40    TX  Established Campground          245 42.5300
# 41    TX       Informal Campsite          195 33.8500
# 42    TX                 Showers            6  1.0400
# 43    TX                   Water           24  4.1700
# 44    TX            Wild Camping          106 18.4000
# 45    WY  Established Campground           92 30.8700
# 46    WY       Informal Campsite           35 11.7400
# 47    WY                 Showers            8  2.6800
# 48    WY                   Water           16  5.3700
# 49    WY            Wild Camping          147 49.3300

# %%
# just keep major classes
wild_est = counts[counts['Category'].isin(['Established Campground', 'Wild Camping'])].copy()
#counts[counts['%'] > 20]
wild_est['pct_total'] = round(wild_est['Description'].div(wild_est.groupby('State')['Description'].transform('sum'))*100, 2)

# %%
wild_est = wild_est.drop(['%'], axis=1)
wild_est
# Out:
#    State                Category  Description  pct_total
# 0     AK  Established Campground          136    38.6400
# 4     AK            Wild Camping          216    61.3600
# 5     FL  Established Campground          179    63.0300
# 10    FL            Wild Camping          105    36.9700
# 11    ID  Established Campground          119    43.2700
# 15    ID            Wild Camping          156    56.7300
# 17    MT  Established Campground          187    55.1600
# 21    MT            Wild Camping          152    44.8400
# 23    NM  Established Campground          127    41.3700
# 28    NM            Wild Camping          180    58.6300
# 29    NV  Established Campground           68    35.4200
# 34    NV            Wild Camping          124    64.5800
# 35    NY  Established Campground           82    59.8500
# 39    NY            Wild Camping           55    40.1500
# 40    TX  Established Campground          245    69.8000
# 44    TX            Wild Camping          106    30.2000
# 45    WY  Established Campground           92    38.4900
# 49    WY            Wild Camping          147    61.5100

# %%
# focus on some
wild_est_focus = wild_est[wild_est['State'].isin(['ID', 'MT', 'NM'])]

# %%
wild_est_focus
# Out:
#    State                Category  Description  pct_total
# 11    ID  Established Campground          119    43.2700
# 15    ID            Wild Camping          156    56.7300
# 17    MT  Established Campground          187    55.1600
# 21    MT            Wild Camping          152    44.8400
# 23    NM  Established Campground          127    41.3700
# 28    NM            Wild Camping          180    58.6300

# %%
wild_est_focus.groupby('Category')['Description'].agg('sum')
# Out:
# Category
# Established Campground    433
# Wild Camping              488
# Name: Description, dtype: int64

# %%
wild_est_focus.groupby('Category')['Description'].agg('sum').div(wild_est_focus['Description'].sum())
# Out:
# Category
# Established Campground   0.4701
# Wild Camping             0.5299
# Name: Description, dtype: float64

# %%
cat_counts = USdata_with_est_campgrounds_other_states.loc[:,['Category', 'Description']].groupby(['Category']).agg(
    description_count = ('Description','count'))
cat_counts
total = cat_counts['description_count'].sum()
description_pct = cat_counts.groupby('description_count').apply(lambda x: 100 * x / total)
description_pct
# Out:
#                         description_count
# Category
# Eco-Friendly                       0.0850
# Established Campground            35.0057
# Informal Campsite                 23.3277
# Short-term Parking                 0.1984
# Showers                            1.8991
# Water                              4.3084
# Wild Camping                      35.1757

# %%
USdata_with_est_campgrounds_other_states_TX = USdata_with_est_campgrounds_other_states[USdata_with_est_campgrounds_other_states['State'] == 'TX']

# %%
cat_counts = USdata_with_est_campgrounds_other_states_TX.loc[:,['Category', 'Description']].groupby(['Category']).agg(
    description_count = ('Description','count'))
cat_counts
total = cat_counts['description_count'].sum()
description_pct = cat_counts.groupby('description_count').apply(lambda x: 100 * x / total)
description_pct
# Out:
#                         description_count
# Category
# Established Campground            42.5347
# Informal Campsite                 33.8542
# Showers                            1.0417
# Water                              4.1667
# Wild Camping                      18.4028
