# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline
pd.options.display.float_format = '{:,.2f}'.format
plt.style.use('seaborn-white')
# colorblind safe
plt.style.use('seaborn-colorblind')
plt.style.use('tableau-colorblind10')

# width and precision for f strings
width = 10
precision = 4

# default sizes for plots
# https://matplotlib.org/3.3.0/tutorials/introductory/customizing.html#customizing-with-matplotlibrc-files
plt.rcParams['figure.figsize'] = [10, 6]
plt.rcParams['font.size'] = 16
plt.rcParams['legend.fontsize'] = 'large'
plt.rcParams['figure.titlesize'] = 'medium'
plt.rcParams['lines.linewidth'] = 2

# other settings
pd.options.display.float_format = '{:,.4f}'.format
pd.set_option("display.precision", 3)
np.set_printoptions(precision=3, suppress=True)
# %load_ext autoreload
# %autoreload 2
pd.set_option('display.max_columns', None)
# %config IPCompleter.greedy=True
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# setup dir and import helper functions
import sys, os
sys.path.append(os.path.join(os.path.dirname(sys.path[0]),'src'))
import helper_funcs as my_funcs
import re

# %%
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

# %%
names = states

# %%
len(names)
# Out:
# 51

# %%
# filter US data for this - this is what I'm calling "all US data"
# forgot that I only pulled closed from all 50 states
USdata = pd.read_csv('../data/USdata_all_zip_states_combined_cleaned_NEW.csv')

# %%
list(USdata['Category'].unique())
# Out:
# ['Established Campground',
#  'Wild Camping',
#  'Informal Campsite',
#  'Showers',
#  'Water',
#  'Short-term Parking',
#  'Eco-Friendly']

# %%
USdata['State'].unique()
# Out:
# array(['CA', 'UT', 'AK', 'OR', 'WA', 'WV', 'MD', 'MT', 'AZ', 'SE', 'NV',
#        'CO', 'NM', 'TX', 'TN', 'KY', 'FL', 'ME', 'NC', 'VA', 'IL', 'SD',
#        'NE', 'OH', 'WY', 'AR', 'MI', 'ID', 'MS', 'OK', 'GA', 'AL', 'LA',
#        'SC', 'NY', 'VT', 'KS', 'MO', 'RV', 'US', 'NW', 'PA', 'WI', 'MA',
#        'MN', 'NJ', 'SW', 'ND', 'IN', 'HI', 'IA', 'AB', 'NH', 'YT', 'DE',
#        'CT', 'BC', 'RI', 'N.L.', 'NB', nan, 'DC', 'ON', 'QC', 'S.L.P.',
#        'Ver.', 'Nay.', 'NS', 'B.C.', 'Pue.'], dtype=object)

# %%
All_USdata = USdata[USdata['State'].isin(names)]

# %%
All_USdata['State'].unique()
# Out:
# array(['CA', 'UT', 'AK', 'OR', 'WA', 'WV', 'MD', 'MT', 'AZ', 'NV', 'CO',
#        'NM', 'TX', 'TN', 'KY', 'FL', 'ME', 'NC', 'VA', 'IL', 'SD', 'NE',
#        'OH', 'WY', 'AR', 'MI', 'ID', 'MS', 'OK', 'GA', 'AL', 'LA', 'SC',
#        'NY', 'VT', 'KS', 'MO', 'PA', 'WI', 'MA', 'MN', 'NJ', 'ND', 'IN',
#        'HI', 'IA', 'NH', 'DE', 'CT', 'RI', 'DC'], dtype=object)

# %%
All_USdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11786 entries, 0 to 12411
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Location                   2212 non-null   object
#  1   Name                       11786 non-null  object
#  2   Category                   11786 non-null  object
#  3   Description                11785 non-null  object
#  4   Latitude                   11786 non-null  float64
#  5   Longitude                  11786 non-null  float64
#  6   Altitude                   11490 non-null  float64
#  7   Date verified              11786 non-null  object
#  8   Open                       11786 non-null  object
#  9   Electricity                11007 non-null  object
#  10  Wifi                       11007 non-null  object
#  11  Kitchen                    11007 non-null  object
#  12  Parking                    0 non-null      float64
#  13  Restaurant                 11007 non-null  object
#  14  Showers                    11266 non-null  object
#  15  Water                      11007 non-null  object
#  16  Toilets                    11007 non-null  object
#  17  Big rig friendly           11007 non-null  object
#  18  Tent friendly              11007 non-null  object
#  19  Pet friendly               11007 non-null  object
#  20  Sanitation dump station    3714 non-null   object
#  21  Outdoor gear               0 non-null      float64
#  22  Groceries                  0 non-null      float64
#  23  Artesian goods             0 non-null      float64
#  24  Bakery                     0 non-null      float64
#  25  Rarity in this area        0 non-null      float64
#  26  Repairs vehicles           0 non-null      float64
#  27  Repairs motorcycles        0 non-null      float64
#  28  Repairs bicycles           0 non-null      float64
#  29  Sells parts                0 non-null      float64
#  30  Recycles batteries         21 non-null     object
#  31  Recycles oil               21 non-null     object
#  32  Bio fuel                   21 non-null     object
#  33  Electric vehicle charging  21 non-null     object
#  34  Composting sawdust         21 non-null     object
#  35  Recycling center           21 non-null     object
#  36  zip_code                   9574 non-null   object
#  37  State                      11786 non-null  object
# dtypes: float64(13), object(25)
# memory usage: 3.5+ MB

# %%
All_USdata.head()
# Out:
#                                                 Location  \
# 0  Borrego Salton Seaway, Borrego Springs, CA 92004, USA
# 1          Stateline Campground Rd, Kanab, UT 84741, USA
# 2                   Glenn Hwy, Glennallen, AK 99588, USA
# 3       Beverly Beach State Park, Newport, OR 97365, USA
# 4                    Cottell Ln, Coos Bay, OR 97420, USA
#
#                                    Name                Category  \
# 0                 Arroyo Salado Camping  Established Campground
# 1                 State Line Campground  Established Campground
# 2  Tolsona River RV Park and Campground  Established Campground
# 3              Beverly Beach State Park  Established Campground
# 4                 Sunset Bay State Park  Established Campground
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Description  \
# 0                                                                                                                                                                                                                                                                                                                                                                      Free with two vault toilets, nothing else exists  Campsite fires are required to be in some sort of metal container.  Perhaps ~10 sites for car camping.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Cute free BLM camping in near  TH baths.
# 2                                                                                                                                                                                                                                                                                                                                                                             An old standby for us.  Multiple sites for large or small RV's and tents along a windy creek.  Hot showers cost .25/minute, wifi close to office.
# 3  This is a great beach for a first night on the Oregon coast.  It is a very nice State Park campground with great beach access under a highway 101 overpass.  A Beautiful old growth loop-system campground with full hookups, tent sites (good selection), hot showers, clean bathrooms, but no wifi available. It is not free (which is hard to do in Oregon) but the price was $17 for a tent site. Be sure to check the pay period dates though as we were there in a "Discovery" period ($17 was between Oct 1-Apr 30).
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                 Another night, another campground.  Full hookups, hot showers, no wifi  Price:  $15/tent site
#
#    Latitude  Longitude  Altitude            Date verified Open  \
# 0   33.2802  -116.1458    0.0000  2020-02-16 14:20:45 UTC  Yes
# 1   37.0013  -112.0356    0.0000  2019-09-29 09:53:41 UTC  Yes
# 2   62.0954  -145.9805    0.0000  2016-05-27 11:38:27 UTC  Yes
# 3   44.7288  -124.0555    0.0000  2020-02-07 00:00:00 UTC  Yes
# 4   43.3308  -124.3707    2.6656  2020-06-27 00:00:00 UTC  Yes
#
#       Electricity     Wifi  Kitchen  Parking Restaurant  Showers    Water  \
# 0              No       No       No      nan         No       No       No
# 1              No       No       No      nan         No       No       No
# 2         Unknown  Unknown  Unknown      nan    Unknown  Unknown  Unknown
# 3  Yes - At Sites       No       No      nan         No      Hot  Potable
# 4  Yes - At Sites       No       No      nan         No      Hot  Potable
#
#          Toilets Big rig friendly Tent friendly Pet friendly  \
# 0    Pit Toilets              Yes           Yes          Yes
# 1    Pit Toilets               No           Yes          Yes
# 2        Unknown          Unknown       Unknown      Unknown
# 3  Running Water              Yes           Yes          Yes
# 4  Running Water              Yes           Yes          Yes
#
#   Sanitation dump station  Outdoor gear  Groceries  Artesian goods  Bakery  \
# 0                 Unknown           nan        nan             nan     nan
# 1                 Unknown           nan        nan             nan     nan
# 2                 Unknown           nan        nan             nan     nan
# 3                 Unknown           nan        nan             nan     nan
# 4                 Unknown           nan        nan             nan     nan
#
#    Rarity in this area  Repairs vehicles  Repairs motorcycles  \
# 0                  nan               nan                  nan
# 1                  nan               nan                  nan
# 2                  nan               nan                  nan
# 3                  nan               nan                  nan
# 4                  nan               nan                  nan
#
#    Repairs bicycles  Sells parts Recycles batteries Recycles oil Bio fuel  \
# 0               nan          nan                NaN          NaN      NaN
# 1               nan          nan                NaN          NaN      NaN
# 2               nan          nan                NaN          NaN      NaN
# 3               nan          nan                NaN          NaN      NaN
# 4               nan          nan                NaN          NaN      NaN
#
#   Electric vehicle charging Composting sawdust Recycling center zip_code State
# 0                       NaN                NaN              NaN      NaN    CA
# 1                       NaN                NaN              NaN      NaN    UT
# 2                       NaN                NaN              NaN      NaN    AK
# 3                       NaN                NaN              NaN      NaN    OR
# 4                       NaN                NaN              NaN      NaN    OR

# %%
# look at potential binary columns for wild & est first
All_USdata_est_wild = All_USdata[All_USdata['Category'].isin(['Established Campground','Wild Camping'])]

# %%
All_USdata_est_wild.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8325 entries, 0 to 12410
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Location                   1720 non-null   object
#  1   Name                       8325 non-null   object
#  2   Category                   8325 non-null   object
#  3   Description                8324 non-null   object
#  4   Latitude                   8325 non-null   float64
#  5   Longitude                  8325 non-null   float64
#  6   Altitude                   8108 non-null   float64
#  7   Date verified              8325 non-null   object
#  8   Open                       8325 non-null   object
#  9   Electricity                8325 non-null   object
#  10  Wifi                       8325 non-null   object
#  11  Kitchen                    8325 non-null   object
#  12  Parking                    0 non-null      float64
#  13  Restaurant                 8325 non-null   object
#  14  Showers                    8325 non-null   object
#  15  Water                      8325 non-null   object
#  16  Toilets                    8325 non-null   object
#  17  Big rig friendly           8325 non-null   object
#  18  Tent friendly              8325 non-null   object
#  19  Pet friendly               8325 non-null   object
#  20  Sanitation dump station    3714 non-null   object
#  21  Outdoor gear               0 non-null      float64
#  22  Groceries                  0 non-null      float64
#  23  Artesian goods             0 non-null      float64
#  24  Bakery                     0 non-null      float64
#  25  Rarity in this area        0 non-null      float64
#  26  Repairs vehicles           0 non-null      float64
#  27  Repairs motorcycles        0 non-null      float64
#  28  Repairs bicycles           0 non-null      float64
#  29  Sells parts                0 non-null      float64
#  30  Recycles batteries         0 non-null      object
#  31  Recycles oil               0 non-null      object
#  32  Bio fuel                   0 non-null      object
#  33  Electric vehicle charging  0 non-null      object
#  34  Composting sawdust         0 non-null      object
#  35  Recycling center           0 non-null      object
#  36  zip_code                   6605 non-null   object
#  37  State                      8325 non-null   object
# dtypes: float64(13), object(25)
# memory usage: 2.5+ MB

# %%
All_USdata_est_wild['Toilets'].unique()
# Out:
# array(['Pit Toilets', 'Unknown', 'Running Water', 'No', 'Yes'],
#       dtype=object)

# %%
All_USdata_est_wild.loc[:,['Category', 'Description']].groupby(['Category']).agg('count')
# Out:
#                         Description
# Category
# Established Campground         3713
# Wild Camping                   4611

# %%
cat_counts = All_USdata_est_wild.loc[:,['Category', 'Description']].groupby(['Category']).agg(
    description_pct = ('Description','count'))
cat_counts
total = cat_counts['description_pct'].sum()
description_pct = cat_counts.groupby('description_pct').apply(lambda x: 100 * x / total)
description_pct
# Out:
#                         description_pct
# Category
# Established Campground          44.6060
# Wild Camping                    55.3940

# %%
All_USdata_est_wild.loc[:,['Category', 'Description', 'Toilets']].groupby(['Toilets', 'Category']).agg('count')
# Out:
#                                       Description
# Toilets       Category
# No            Established Campground          255
#               Wild Camping                   3960
# Pit Toilets   Established Campground         1317
#               Wild Camping                    394
# Running Water Established Campground         2002
#               Wild Camping                    165
# Unknown       Established Campground           88
#               Wild Camping                     80
# Yes           Established Campground           51
#               Wild Camping                     12

# %%
All_USdata_est_wild.loc[:,['Category', 'Description', 'Electricity']].groupby(['Electricity', 'Category']).agg('count')
# Out:
#                                            Description
# Electricity        Category
# No                 Established Campground         1662
#                    Wild Camping                   4520
# Unknown            Established Campground          104
#                    Wild Camping                     47
# Yes                Established Campground           50
# Yes - At Sites     Established Campground         1713
#                    Wild Camping                     21
# Yes - Not at Sites Established Campground          184
#                    Wild Camping                     23

# %%
All_USdata_est_wild.loc[:,['Category', 'Description', 'Water']].groupby(['Water', 'Category']).agg('count')
# Out:
#                                        Description
# Water          Category
# Natural Source Established Campground          337
#                Wild Camping                    792
# No             Established Campground          617
#                Wild Camping                   3491
# Non-Potable    Established Campground          161
#                Wild Camping                     64
# Potable        Established Campground         2125
#                Wild Camping                     71
# Unknown        Established Campground          166
#                Wild Camping                    118
# Yes            Established Campground          307
#                Wild Camping                     75

# %%
# for water, toilets, electricity, make binary cols for each - these seem interesting and don't split with wild/est
All_USdata_est_wild['water_binary'] = 0
yes = ['Potable', 'Yes']
# df['color'] = np.where(df['Set']=='Z', 'green', 'red')
All_USdata_est_wild['water_binary'][All_USdata_est_wild['Water'].isin(yes)] = 1
# Out:
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/pandas/core/series.py:1020: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
All_USdata_est_wild.head()
# Out:
#                                                 Location  \
# 0  Borrego Salton Seaway, Borrego Springs, CA 92004, USA
# 1          Stateline Campground Rd, Kanab, UT 84741, USA
# 2                   Glenn Hwy, Glennallen, AK 99588, USA
# 3       Beverly Beach State Park, Newport, OR 97365, USA
# 4                    Cottell Ln, Coos Bay, OR 97420, USA
#
#                                    Name                Category  \
# 0                 Arroyo Salado Camping  Established Campground
# 1                 State Line Campground  Established Campground
# 2  Tolsona River RV Park and Campground  Established Campground
# 3              Beverly Beach State Park  Established Campground
# 4                 Sunset Bay State Park  Established Campground
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Description  \
# 0                                                                                                                                                                                                                                                                                                                                                                      Free with two vault toilets, nothing else exists  Campsite fires are required to be in some sort of metal container.  Perhaps ~10 sites for car camping.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Cute free BLM camping in near  TH baths.
# 2                                                                                                                                                                                                                                                                                                                                                                             An old standby for us.  Multiple sites for large or small RV's and tents along a windy creek.  Hot showers cost .25/minute, wifi close to office.
# 3  This is a great beach for a first night on the Oregon coast.  It is a very nice State Park campground with great beach access under a highway 101 overpass.  A Beautiful old growth loop-system campground with full hookups, tent sites (good selection), hot showers, clean bathrooms, but no wifi available. It is not free (which is hard to do in Oregon) but the price was $17 for a tent site. Be sure to check the pay period dates though as we were there in a "Discovery" period ($17 was between Oct 1-Apr 30).
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                 Another night, another campground.  Full hookups, hot showers, no wifi  Price:  $15/tent site
#
#    Latitude  Longitude  Altitude            Date verified Open  \
# 0   33.2802  -116.1458    0.0000  2020-02-16 14:20:45 UTC  Yes
# 1   37.0013  -112.0356    0.0000  2019-09-29 09:53:41 UTC  Yes
# 2   62.0954  -145.9805    0.0000  2016-05-27 11:38:27 UTC  Yes
# 3   44.7288  -124.0555    0.0000  2020-02-07 00:00:00 UTC  Yes
# 4   43.3308  -124.3707    2.6656  2020-06-27 00:00:00 UTC  Yes
#
#       Electricity     Wifi  Kitchen  Parking Restaurant  Showers    Water  \
# 0              No       No       No      nan         No       No       No
# 1              No       No       No      nan         No       No       No
# 2         Unknown  Unknown  Unknown      nan    Unknown  Unknown  Unknown
# 3  Yes - At Sites       No       No      nan         No      Hot  Potable
# 4  Yes - At Sites       No       No      nan         No      Hot  Potable
#
#          Toilets Big rig friendly Tent friendly Pet friendly  \
# 0    Pit Toilets              Yes           Yes          Yes
# 1    Pit Toilets               No           Yes          Yes
# 2        Unknown          Unknown       Unknown      Unknown
# 3  Running Water              Yes           Yes          Yes
# 4  Running Water              Yes           Yes          Yes
#
#   Sanitation dump station  Outdoor gear  Groceries  Artesian goods  Bakery  \
# 0                 Unknown           nan        nan             nan     nan
# 1                 Unknown           nan        nan             nan     nan
# 2                 Unknown           nan        nan             nan     nan
# 3                 Unknown           nan        nan             nan     nan
# 4                 Unknown           nan        nan             nan     nan
#
#    Rarity in this area  Repairs vehicles  Repairs motorcycles  \
# 0                  nan               nan                  nan
# 1                  nan               nan                  nan
# 2                  nan               nan                  nan
# 3                  nan               nan                  nan
# 4                  nan               nan                  nan
#
#    Repairs bicycles  Sells parts Recycles batteries Recycles oil Bio fuel  \
# 0               nan          nan                NaN          NaN      NaN
# 1               nan          nan                NaN          NaN      NaN
# 2               nan          nan                NaN          NaN      NaN
# 3               nan          nan                NaN          NaN      NaN
# 4               nan          nan                NaN          NaN      NaN
#
#   Electric vehicle charging Composting sawdust Recycling center zip_code  \
# 0                       NaN                NaN              NaN      NaN
# 1                       NaN                NaN              NaN      NaN
# 2                       NaN                NaN              NaN      NaN
# 3                       NaN                NaN              NaN      NaN
# 4                       NaN                NaN              NaN      NaN
#
#   State  water_binary
# 0    CA             0
# 1    UT             0
# 2    AK             0
# 3    OR             1
# 4    OR             1

# %%
All_USdata_est_wild['toilets_binary'] = 0
yes = ['Pit Toilets', 'Yes', 'Running Water']
# df['color'] = np.where(df['Set']=='Z', 'green', 'red')
All_USdata_est_wild['toilets_binary'][All_USdata_est_wild['Toilets'].isin(yes)] = 1
# Out:
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/pandas/core/series.py:1020: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
All_USdata_est_wild.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8325 entries, 0 to 12410
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Location                   1720 non-null   object
#  1   Name                       8325 non-null   object
#  2   Category                   8325 non-null   object
#  3   Description                8324 non-null   object
#  4   Latitude                   8325 non-null   float64
#  5   Longitude                  8325 non-null   float64
#  6   Altitude                   8108 non-null   float64
#  7   Date verified              8325 non-null   object
#  8   Open                       8325 non-null   object
#  9   Electricity                8325 non-null   object
#  10  Wifi                       8325 non-null   object
#  11  Kitchen                    8325 non-null   object
#  12  Parking                    0 non-null      float64
#  13  Restaurant                 8325 non-null   object
#  14  Showers                    8325 non-null   object
#  15  Water                      8325 non-null   object
#  16  Toilets                    8325 non-null   object
#  17  Big rig friendly           8325 non-null   object
#  18  Tent friendly              8325 non-null   object
#  19  Pet friendly               8325 non-null   object
#  20  Sanitation dump station    3714 non-null   object
#  21  Outdoor gear               0 non-null      float64
#  22  Groceries                  0 non-null      float64
#  23  Artesian goods             0 non-null      float64
#  24  Bakery                     0 non-null      float64
#  25  Rarity in this area        0 non-null      float64
#  26  Repairs vehicles           0 non-null      float64
#  27  Repairs motorcycles        0 non-null      float64
#  28  Repairs bicycles           0 non-null      float64
#  29  Sells parts                0 non-null      float64
#  30  Recycles batteries         0 non-null      object
#  31  Recycles oil               0 non-null      object
#  32  Bio fuel                   0 non-null      object
#  33  Electric vehicle charging  0 non-null      object
#  34  Composting sawdust         0 non-null      object
#  35  Recycling center           0 non-null      object
#  36  zip_code                   6605 non-null   object
#  37  State                      8325 non-null   object
#  38  water_binary               8325 non-null   int64
#  39  toilets_binary             8325 non-null   int64
# dtypes: float64(13), int64(2), object(25)
# memory usage: 2.9+ MB

# %%
All_USdata_est_wild
# Out:
#                                                     Location  \
# 0      Borrego Salton Seaway, Borrego Springs, CA 92004, USA
# 1              Stateline Campground Rd, Kanab, UT 84741, USA
# 2                       Glenn Hwy, Glennallen, AK 99588, USA
# 3           Beverly Beach State Park, Newport, OR 97365, USA
# 4                        Cottell Ln, Coos Bay, OR 97420, USA
# ...                                                      ...
# 12403                    Unnamed Road, Fallon, NV 89406, USA
# 12404              2560 E Lucky Ln, Flagstaff, AZ 86004, USA
# 12408        Mexican Hat Rock Rd, Mexican Hat, UT 84531, USA
# 12409        818-898 E Locust St, San Antonio, TX 78212, USA
# 12410                                   Leeds, ME 04263, USA
#
#                                          Name                Category  \
# 0                       Arroyo Salado Camping  Established Campground
# 1                       State Line Campground  Established Campground
# 2        Tolsona River RV Park and Campground  Established Campground
# 3                    Beverly Beach State Park  Established Campground
# 4                       Sunset Bay State Park  Established Campground
# ...                                       ...                     ...
# 12403                    hidden cave BLM site            Wild Camping
# 12404               Lucky Lane street parking            Wild Camping
# 12408  Between San Juan river and Mexican Hat            Wild Camping
# 12409                    Neighborhood Parking            Wild Camping
# 12410                       Pull out to river            Wild Camping
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Description  \
# 0                                                                                                                                                                                                                                                                                                                                                                          Free with two vault toilets, nothing else exists  Campsite fires are required to be in some sort of metal container.  Perhaps ~10 sites for car camping.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Cute free BLM camping in near  TH baths.
# 2                                                                                                                                                                                                                                                                                                                                                                                 An old standby for us.  Multiple sites for large or small RV's and tents along a windy creek.  Hot showers cost .25/minute, wifi close to office.
# 3      This is a great beach for a first night on the Oregon coast.  It is a very nice State Park campground with great beach access under a highway 101 overpass.  A Beautiful old growth loop-system campground with full hookups, tent sites (good selection), hot showers, clean bathrooms, but no wifi available. It is not free (which is hard to do in Oregon) but the price was $17 for a tent site. Be sure to check the pay period dates though as we were there in a "Discovery" period ($17 was between Oct 1-Apr 30).
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                     Another night, another campground.  Full hookups, hot showers, no wifi  Price:  $15/tent site
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
#
# ...            ...                     ...           ...        ...
# 12403          Yes                     NaN           nan        nan
# 12404          Yes                     NaN           nan        nan
# 12408      Unknown                     NaN           nan        nan
# 12409          Yes                     NaN           nan        nan
# 12410          Yes                     NaN           nan        nan
#
#        Artesian goods  Bakery  Rarity in this area  Repairs vehicles  \
# 0                 nan     nan                  nan               nan
# 1                 nan     nan                  nan               nan
# 2                 nan     nan                  nan               nan
# 3                 nan     nan                  nan               nan
# 4                 nan     nan                  nan               nan
# ...               ...     ...                  ...               ...
# 12403             nan     nan                  nan               nan
# 12404             nan     nan                  nan               nan
# 12408             nan     nan                  nan               nan
# 12409             nan     nan                  nan               nan
# 12410             nan     nan                  nan               nan
#
#        Repairs motorcycles  Repairs bicycles  Sells parts Recycles batteries  \
# 0                      nan               nan          nan                NaN
# 1                      nan               nan          nan                NaN
# 2                      nan               nan          nan                NaN
# 3                      nan               nan          nan                NaN
# 4                      nan               nan          nan                NaN
# ...                    ...               ...          ...                ...
# 12403                  nan               nan          nan                NaN
# 12404                  nan               nan          nan                NaN
# 12408                  nan               nan          nan                NaN
# 12409                  nan               nan          nan                NaN
# 12410                  nan               nan          nan                NaN
#
#       Recycles oil Bio fuel Electric vehicle charging Composting sawdust  \
# 0              NaN      NaN                       NaN                NaN
# 1              NaN      NaN                       NaN                NaN
# 2              NaN      NaN                       NaN                NaN
# 3              NaN      NaN                       NaN                NaN
# 4              NaN      NaN                       NaN                NaN
# ...            ...      ...                       ...                ...
# 12403          NaN      NaN                       NaN                NaN
# 12404          NaN      NaN                       NaN                NaN
# 12408          NaN      NaN                       NaN                NaN
# 12409          NaN      NaN                       NaN                NaN
# 12410          NaN      NaN                       NaN                NaN
#
#       Recycling center zip_code State  water_binary  toilets_binary
# 0                  NaN      NaN    CA             0               1
# 1                  NaN      NaN    UT             0               1
# 2                  NaN      NaN    AK             0               0
# 3                  NaN      NaN    OR             1               1
# 4                  NaN      NaN    OR             1               1
# ...                ...      ...   ...           ...             ...
# 12403              NaN      NaN    NV             0               1
# 12404              NaN      NaN    AZ             1               0
# 12408              NaN      NaN    UT             0               0
# 12409              NaN      NaN    TX             0               0
# 12410              NaN      NaN    ME             0               0
#
# [8325 rows x 40 columns]

# %%
# # make lat long col to match with image filenames {prefix}_{i}_{cat}_{zoomlevel}_{lat}_{long}.png'
# All_USdata_est_wild['filename_end'] = All_USdata_est_wild['Category'].astype(str) + '_17_' + \
#                                     All_USdata_est_wild['Latitude'].astype(str) + '_' + \
#                                     All_USdata_est_wild['Longitude'].astype(str) + '.png'

# %%
# pd.set_option('max_colwidth', None)
# All_USdata_est_wild['filename_end'].head()

# %%
directory = '/Users/pault/Desktop/github/CampsitePredict/data/symlink_data/only_unaugmented'

# %%
# get list of images in os.walk order
filelist = []
for root_path, dirs, files in os.walk(directory, followlinks=False):
    for file in files:
        if file.endswith(".png"):
            # only keep original files not augmented
            if not re.search('rot[0-9]{2,3}.png$', file):
                # parse out part of filename
                filelist.append(file[:-4])

# %%
file_df = pd.DataFrame(filelist)

# %%
file_df.to_csv('../data/file_df_for_land.csv', index=False)

# %%
str.replace('__')

# %%
filelist[:10]
# Out:
# ['satimg_CO__352_Wild Camping_17_38.98102_-107.32651',
#  'satimg_ID_7863_Wild Camping_17_43.149667_-111.052531',
#  'satimg_TX_6214_Wild Camping_17_35.2375_-102.83496099999999',
#  'satimg_CO__216_Wild Camping_17_39.337122_-107.660378',
#  'satimg_AZ_6033_Wild Camping_17_34.169239000000005_-110.794278',
#  'satimg_MI_6491_Wild Camping_17_46.76277_-85.02438000000002',
#  'satimg_UT_2806_Wild Camping_17_37.84661_-111.428193',
#  'satimg_AK_12112_Wild Camping_17_63.887170999999995_-149.348656',
#  'satimg_OR_6000_Wild Camping_17_44.413897_-120.495699',
#  'satimg_PA_2971_Wild Camping_17_41.430395_-78.883376']

# %%
# make index to reorder the df the same
image_file_df = pd.DataFrame(filelist, columns =['filename'])

# %%
# image_file_df.to_csv('../data/example_to_split.csv')

# %%
def func(f, n=6):
    result =['.'.join([j[:n] for j in i.split('.')]) for i in f['filename'].split('_')[-2:]]
    return {'lat_from_file':result[0], 'long_from_file':result[1]}

# %%
latlongs = image_file_df[['filename']].apply(func, axis = 1, result_type = 'expand')

# %%
image_file_df = pd.concat([image_file_df, latlongs], axis=1)

# %%
# split = image_file_df['filename'].str.rsplit('_', 2, expand=True)

# %%
# split = split.rename(columns={0: "file_start", 1: "lat", 2: "long"})

# %%
# image_file_df['lat_from_file'] = split.iloc[:,0].astype('str')
# image_file_df['long_from_file'] = split.iloc[:,1].astype('str')
# image_file_df['lat_from_file']
# image_file_df['long_from_file'] float( '%.3f'%(x) )df
# image_file_df['lat_from_file'].apply(lambda x: '%.3f'%(x))

# %%
image_file_df['order'] = image_file_df.index

# %%
len(image_file_df['filename'].unique())
# Out:
# 7855

# %%
len(image_file_df['filename'].unique())
# Out:
# 7855

# %%
All_USdata_est_wild[All_USdata_est_wild.duplicated()]
# Out:
#      Location                                    Name                Category  \
# 2630      NaN  Lebanon Hills Regional Park Campground  Established Campground
# 2938      NaN       Greensport RV Park and Campground  Established Campground
# 3231      NaN                  Mother Neff State Park  Established Campground
#
#                                                                                                                                                                                                                                                                                                                                                                                                                            Description  \
# 2630                                                                                                                                                                              Established campground. Very busy during the summer. Plan ahead if possible. You might get one night at this time of year. Seems typical for places like this near a big metropolis. Pros: It's close in. Cons: It's close in. Plan ahead and enjoy.
# 2938  Welcome to Greensport RV Park located at Historic Greensport on Neely Henry Lake in Ashville, AL. Bring your RV or Camper to enjoy fishing, boating, camping, picnicking, and swimming. All sites have full hook-ups, 30/50 amp electric, water, and sewer. We have 32 sites completed at this time and will continue adding amenities as we develop. Come check out what our peaceful retreat has to offer you and your family!
# 3231                                                                                                                                                                                                                                               Nice little park named after Isabella Neff, mother of Pat Neff, her youngest son, who became governor of Texas in 1921.  She donated the first 6 acres for the park upon her death.
#
#       Latitude  Longitude  Altitude            Date verified Open  \
# 2630   44.7789   -93.1639       nan  2019-07-27 00:00:00 UTC  Yes
# 2938   33.8483   -86.0784       nan  2019-09-30 00:00:00 UTC  Yes
# 3231   31.3327   -97.4643       nan  2019-09-22 00:00:00 UTC  Yes
#
#          Electricity           Wifi  Kitchen  Parking Restaurant  Showers  \
# 2630  Yes - At Sites             No       No      nan         No  Unknown
# 2938  Yes - At Sites  Yes - Average  Unknown      nan    Unknown      Hot
# 3231             Yes        Unknown       No      nan         No      Hot
#
#         Water        Toilets Big rig friendly Tent friendly Pet friendly  \
# 2630  Potable            Yes              Yes           Yes          Yes
# 2938      Yes  Running Water              Yes            No          Yes
# 3231  Potable  Running Water              Yes           Yes          Yes
#
#      Sanitation dump station  Outdoor gear  Groceries  Artesian goods  Bakery  \
# 2630                 Unknown           nan        nan             nan     nan
# 2938                 Unknown           nan        nan             nan     nan
# 3231                 Unknown           nan        nan             nan     nan
#
#       Rarity in this area  Repairs vehicles  Repairs motorcycles  \
# 2630                  nan               nan                  nan
# 2938                  nan               nan                  nan
# 3231                  nan               nan                  nan
#
#       Repairs bicycles  Sells parts Recycles batteries Recycles oil Bio fuel  \
# 2630               nan          nan                NaN          NaN      NaN
# 2938               nan          nan                NaN          NaN      NaN
# 3231               nan          nan                NaN          NaN      NaN
#
#      Electric vehicle charging Composting sawdust Recycling center zip_code  \
# 2630                       NaN                NaN              NaN    55123
# 2938                       NaN                NaN              NaN    35953
# 3231                       NaN                NaN              NaN    76557
#
#      State  water_binary  toilets_binary
# 2630    MN             1               1
# 2938    AL             1               1
# 3231    TX             1               1

# %%
All_USdata_est_wild.drop_duplicates(inplace=True)
# Out:
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
All_USdata_est_wild.shape
# Out:
# (8322, 40)

# %%
All_USdata_est_wild['latlong_test'] = All_USdata_est_wild['Latitude'].astype('str') + '_' + All_USdata_est_wild['Longitude'].astype('str')
#
# Out:
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
image_file_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7855 entries, 0 to 7854
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   filename        7855 non-null   object
#  1   lat_from_file   7855 non-null   object
#  2   long_from_file  7855 non-null   object
#  3   order           7855 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 245.6+ KB

# %%
image_file_df2 = image_file_df.copy()
image_file_df2['latlong_test'] = image_file_df2['lat_from_file'].astype('str') + '_' + image_file_df2['long_from_file'].astype('str')

# %%
image_file_df2.head()
# Out:
#                                                         filename  \
# 0             satimg_CO__352_Wild Camping_17_38.98102_-107.32651
# 1           satimg_ID_7863_Wild Camping_17_43.149667_-111.052531
# 2     satimg_TX_6214_Wild Camping_17_35.2375_-102.83496099999999
# 3           satimg_CO__216_Wild Camping_17_39.337122_-107.660378
# 4  satimg_AZ_6033_Wild Camping_17_34.169239000000005_-110.794278
#
#   lat_from_file long_from_file  order           latlong_test
# 0      38.98102     -107.32651      0    38.98102_-107.32651
# 1     43.149667    -111.052531      1  43.149667_-111.052531
# 2       35.2375    -102.834960      2    35.2375_-102.834960
# 3     39.337122    -107.660378      3  39.337122_-107.660378
# 4     34.169239    -110.794278      4  34.169239_-110.794278

# %%
image_file_df2 = image_file_df.copy()
image_file_df2['latlong_test'] = image_file_df2['lat_from_file'].astype('str') + '_' + image_file_df2['long_from_file'].astype('str')
# Out:
#                                                         filename  \
# 0             satimg_CO__352_Wild Camping_17_38.98102_-107.32651
# 1           satimg_ID_7863_Wild Camping_17_43.149667_-111.052531
# 2     satimg_TX_6214_Wild Camping_17_35.2375_-102.83496099999999
# 3           satimg_CO__216_Wild Camping_17_39.337122_-107.660378
# 4  satimg_AZ_6033_Wild Camping_17_34.169239000000005_-110.794278
#
#   lat_from_file long_from_file  order           latlong_test
# 0      38.98102     -107.32651      0    38.98102_-107.32651
# 1     43.149667    -111.052531      1  43.149667_-111.052531
# 2       35.2375    -102.834960      2    35.2375_-102.834960
# 3     39.337122    -107.660378      3  39.337122_-107.660378
# 4     34.169239    -110.794278      4  34.169239_-110.794278

# %%
duplicated = All_USdata_est_wild[All_USdata_est_wild['latlong_test'].duplicated()]
duplicated.to_csv('../data/duplicated_sites_latlong.csv')

# %%
duplicated['']
# Out:
#                                     Location  \
# 783    911 Hemlock St, Seward, AK 99664, USA
# 947                                      NaN
# 1177                                     NaN
# 1178                                     NaN
# 1832                                     NaN
# 1833                                     NaN
# 2352                                     NaN
# 3080                                     NaN
# 3363                                     NaN
# 5506                                     NaN
# 10247                                    NaN
# 10541                                    NaN
# 11856       US-183, Elm Creek, NE 68836, USA
#
#                                         Name                Category  \
# 783       Williwaw Forest Service Campground  Established Campground
# 947                     Poe Paddy State Park  Established Campground
# 1177                 Copper Mountain RV Park  Established Campground
# 1178                 The Scenic Road RV Park  Established Campground
# 1832   Moose River Plains FREE camp site #64  Established Campground
# 1833   Moose River Plains FREE camp site #62  Established Campground
# 2352                   Delaware State Forest  Established Campground
# 3080                        Dos Rios RV Park  Established Campground
# 3363                    Home Stay Campground  Established Campground
# 5506            Challis NF dispersed camping            Wild Camping
# 10247             Foster Bay Recreation Area            Wild Camping
# 10541                        Elgin Park Loop            Wild Camping
# 11856                          Blue Hole WMA            Wild Camping
#
#                                              Description  Latitude  Longitude  \
# 783    Nice Forest Service campground, sites are very...   60.1332  -149.4298
# 947    $15 campsites here with quite decent bathrooms...   40.8341   -77.4174
# 1177   Location has been updated. \r\n\r\n10 min sout...   32.6882  -113.9551
# 1178   Private park in Quartzite, AZ. Clean park. On ...   32.6882  -113.9551
# 1832   This is a good site right next to a little riv...   43.6847   -74.7036
# 1833    This is a big open spot but it’s up a steep hill   43.6847   -74.7036
# 2352   Very quiet and secluded feel.  Only 5 sites al...   41.1152   -75.2196
# 3080   On the Llano River with RV and tent sites rive...   30.6510   -99.2500
# 3363   A great little spot just a few minutes off 26,...   33.4485   -80.7045
# 5506   Another spot. Close to the 21 byway, but still...   44.2563  -115.0453
# 10247  Quiet, out of the way wild camp, with one picn...   44.7276  -101.0638
# 10541  WY, Buffalo area. Boon Dock, Elgin Park Loop R...   44.2683  -106.9019
# 11856  Wildlife Management Area (Nebraska MWA) at Blu...   40.6876   -99.3831
#
#         Altitude            Date verified Open         Electricity  \
# 783      -1.0000  2017-06-22 00:00:00 UTC  Yes                  No
# 947          nan  2016-07-29 12:52:45 UTC  Yes  Yes - Not at Sites
# 10541     nan                  nan               nan                  nan
# 11856     nan                  nan               nan                  nan
#
#        Repairs bicycles  Sells parts Recycles batteries Recycles oil Bio fuel  \
# 783                 nan          nan                NaN          NaN      NaN
# 947                 nan          nan                NaN          NaN      NaN
# 1177                nan          nan                NaN          NaN      NaN
# 1178                nan          nan                NaN          NaN      NaN
# 1832                nan          nan                NaN          NaN      NaN
# 1833                nan          nan                NaN          NaN      NaN
# 2352                nan          nan                NaN          NaN      NaN
# 3080                nan          nan                NaN          NaN      NaN
# 3363                nan          nan                NaN          NaN      NaN
# 5506                nan          nan                NaN          NaN      NaN
# 10247               nan          nan                NaN          NaN      NaN
# 10541               nan          nan                NaN          NaN      NaN
# 11856               nan          nan                NaN          NaN      NaN
#
#       Electric vehicle charging Composting sawdust Recycling center zip_code  \
# 783                         NaN                NaN              NaN      NaN
# 947                         NaN                NaN              NaN    16882
# 1177                        NaN                NaN              NaN    85356
# 1178                        NaN                NaN              NaN    85356
# 1832                        NaN                NaN              NaN    13360
# 1833                        NaN                NaN              NaN    13360
# 2352                        NaN                NaN              NaN    18302
# 3080                        NaN                NaN              NaN    76856
# 3363                        NaN                NaN              NaN    29115
# 5506                        NaN                NaN              NaN    83278
# 10247                       NaN                NaN              NaN    57537
# 10541                       NaN                NaN              NaN    82834
# 11856                       NaN                NaN              NaN      NaN
#
#       State  water_binary  toilets_binary                  latlong_test
# 783      AK             0               1         60.133196_-149.429799
# 947      PA             0               1          40.834145_-77.417449
# 1177     AZ             1               1         32.688244_-113.955072
# 1178     AZ             0               1         32.688244_-113.955072
# 1832     NY             0               1          43.684708_-74.703609
# 1833     NY             0               1          43.684708_-74.703609
# 2352     PA             0               1            41.11518_-75.21961
# 3080     TX             1               1               30.65103_-99.25
# 3363     SC             1               1   33.44855_-80.70454000000002
# 5506     ID             0               0         44.256325_-115.045303
# 10247    SD             0               0  44.72762_-101.06381999999999
# 10541    WY             0               0            44.26831_-106.9019
# 11856    NE             0               0            40.68755_-99.38306

# %%
# merge duplicated with images df
please = image_file_df2.merge(All_USdata_est_wild, how='outer', 
                                                  on='latlong_test')

# %%
please.to_csv('../data/hope.csv')

# %%
duplicated_df.to_csv('../data/duplicated_df.csv')

# %%
dup_files_to_delete = duplicated_df.copy()

# %%
dup_files_to_delete['filename'] = dup_files_to_delete['filename']#  + '.png'

# %%
pd.set_option('max_colwidth', None)
dup_files_to_delete_list = set(dup_files_to_delete['filename'].to_list())

# %%
len(dup_files_to_delete_list)
# Out:
# 20

# %%
dup_files_to_delete_list
# Out:
# {'satimg_AK_782_Established Campground_17_60.133196_-149.429799',
#  'satimg_AK_783_Established Campground_17_60.133196_-149.429799',
#  'satimg_AZ_1189_Established Campground_17_32.688244_-113.955072',
#  'satimg_AZ_1190_Established Campground_17_32.688244_-113.955072',
#  'satimg_AZ_944_Established Campground_17_32.688244_-113.955072',
#  'satimg_ID_5505_Wild Camping_17_44.256325_-115.045303',
#  'satimg_ID_5506_Wild Camping_17_44.256325_-115.045303',
#  'satimg_NE_8115_Wild Camping_17_40.68755_-99.38306',
#  'satimg_NE_8116_Wild Camping_17_40.68755_-99.38306',
#  'satimg_NY_1831_Established Campground_17_43.684708_-74.703609',
#  'satimg_NY_1832_Established Campground_17_43.684708_-74.703609',
#  'satimg_NY_1833_Established Campground_17_43.684708_-74.703609',
#  'satimg_PA_2351_Established Campground_17_41.11518_-75.21961',
#  'satimg_PA_2352_Established Campground_17_41.11518_-75.21961',
#  'satimg_PA_946_Established Campground_17_40.834145_-77.417449',
#  'satimg_PA_947_Established Campground_17_40.834145_-77.417449',
#  'satimg_TX_3079_Established Campground_17_30.65103_-99.25',
#  'satimg_TX_3080_Established Campground_17_30.65103_-99.25',
#  'satimg_WY_10540_Wild Camping_17_44.26831_-106.9019',
#  'satimg_WY_10541_Wild Camping_17_44.26831_-106.9019'}

# %%
# add other possibilities
dup_files_to_delete_list_new = []
for filename in dup_files_to_delete_list:
    dup_files_to_delete_list_new.append(filename)
    dup_files_to_delete_list_new.append(filename + '_rot90')
    dup_files_to_delete_list_new.append(filename + '_rot180')
    dup_files_to_delete_list_new.append(filename + '_rot270')

# %%
dup_files_to_delete_list_new = set(dup_files_to_delete_list_new)

# %%
test.replace('.png', '')
# Out:
# 'satimg_ID_5505_Wild Camping_17_44.256325_-115.045303'

# %%
test = dellist[0]
test2 = test.split('_')[:6]
'_'.join(test2)
# Out:
# 'satimg_ID_5505_Wild Camping_17_44.256325'

# %%
# just remove these images...
directory = '/Users/pault/Desktop/github/CampsitePredict/data/sat_images'
dellist = []
for root_path, dirs, files in os.walk(directory, followlinks=False):
    for file in files:
        # just get the first part of the file (to match rot things etc)
        if file.endswith(".png"):
            test = file.replace('.png', '')
#             print(test)
            if test in dup_files_to_delete_list_new:
                print(os.path.join(root_path, file))
#                 os.remove(os.path.join(root_path, file))
                dellist.append(file)

# %%
len(dellist)
# Out:
# 18

# %%
All_USdata_est_wild[All_USdata_est_wild['latlong_test'].duplicated()].count()
# Out:
# Location                      2
# Name                         13
# Category                     13
# Description                  13
# Latitude                     13
# Longitude                    13
# Altitude                      9
# Date verified                13
# Open                         13
# Electricity                  13
# Wifi                         13
# Kitchen                      13
# Parking                       0
# Restaurant                   13
# Showers                      13
# Water                        13
# Toilets                      13
# Big rig friendly             13
# Tent friendly                13
# Pet friendly                 13
# Sanitation dump station       9
# Outdoor gear                  0
# Groceries                     0
# Artesian goods                0
# Bakery                        0
# Rarity in this area           0
# Repairs vehicles              0
# Repairs motorcycles           0
# Repairs bicycles              0
# Sells parts                   0
# Recycles batteries            0
# Recycles oil                  0
# Bio fuel                      0
# Electric vehicle charging     0
# Composting sawdust            0
# Recycling center              0
# zip_code                     11
# State                        13
# water_binary                 13
# toilets_binary               13
# latlong_test                 13
# dtype: int64

# %%
len(All_USdata_est_wild['latlong_test'].unique())
# Out:
# 8309

# %%
All_USdata_est_wild.shape
# Out:
# (8322, 41)

# %%
All_USdata_est_wild.shape[0] - len(All_USdata_est_wild['latlong_test'].unique())
# Out:
# 13

# %%
All_USdata_est_wild_no_dup = All_USdata_est_wild[~All_USdata_est_wild['latlong_test'].duplicated()]

# %%
All_USdata_est_wild_no_dup.shape
# Out:
# (8309, 41)

# %%
image_file_df.shape
# Out:
# (7855, 4)

# %%
image_file_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7855 entries, 0 to 7854
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   filename        7855 non-null   object
#  1   lat_from_file   7855 non-null   object
#  2   long_from_file  7855 non-null   object
#  3   order           7855 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 245.6+ KB

# %%
def func2(col, n=5):
    result = ['.'.join([j[:n] for j in x.split('.')]) for x in col.astype('str')]
#     ['.'.join([j[:n] for j in i.split('.')]) for i in f['filename'].split('_')[-2:]]
    return result

# %%
# [x.split('.') for x in All_USdata_est_wild['Latitude'].astype('str')]

# %%
# ['.'.join([j[:6] for j in x.split('.')]) for x in All_USdata_est_wild['Latitude'].astype('str')]

# %%
# All_USdata_est_wild['Latitude'].split('.')
# ['.'.join([All_USdata_est_wild[:n] for j in i.split('.')])

# %%
# All_USdata_est_wild['Latitude'].apply(func2)

# %%
All_USdata_est_wild_no_dup['lat_from_df'] = ['.'.join([j[:5] for j in x.split('.')]) for x in All_USdata_est_wild_no_dup['Latitude'].astype('str')]
All_USdata_est_wild_no_dup['long_from_df'] = ['.'.join([j[:5] for j in x.split('.')]) for x in All_USdata_est_wild_no_dup['Longitude'].astype('str')]
# Out:
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# All_USdata_est_wild['lat_from_df'] = ['.'.join([j[:6] for j in x.split('.')]) for x in All_USdata_est_wild['Latitude'].astype('str')]
# All_USdata_est_wild['long_from_df'] = ['.'.join([j[:6] for j in x.split('.')]) for x in All_USdata_est_wild['Longitude'].astype('str')]
# Out:
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
All_USdata_est_wild_no_dup.drop('latlong_test', axis=1, inplace=True)
# Out:
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
All_USdata_est_wild_no_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8309 entries, 0 to 12410
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Location                   1718 non-null   object
#  1   Name                       8309 non-null   object
#  2   Category                   8309 non-null   object
#  3   Description                8308 non-null   object
#  4   Latitude                   8309 non-null   float64
#  5   Longitude                  8309 non-null   float64
#  6   Altitude                   8099 non-null   float64
#  7   Date verified              8309 non-null   object
#  8   Open                       8309 non-null   object
#  9   Electricity                8309 non-null   object
#  10  Wifi                       8309 non-null   object
#  11  Kitchen                    8309 non-null   object
#  12  Parking                    0 non-null      float64
#  13  Restaurant                 8309 non-null   object
#  14  Showers                    8309 non-null   object
#  15  Water                      8309 non-null   object
#  16  Toilets                    8309 non-null   object
#  17  Big rig friendly           8309 non-null   object
#  18  Tent friendly              8309 non-null   object
#  19  Pet friendly               8309 non-null   object
#  20  Sanitation dump station    3702 non-null   object
#  21  Outdoor gear               0 non-null      float64
#  22  Groceries                  0 non-null      float64
#  23  Artesian goods             0 non-null      float64
#  24  Bakery                     0 non-null      float64
#  25  Rarity in this area        0 non-null      float64
#  26  Repairs vehicles           0 non-null      float64
#  27  Repairs motorcycles        0 non-null      float64
#  28  Repairs bicycles           0 non-null      float64
#  29  Sells parts                0 non-null      float64
#  30  Recycles batteries         0 non-null      object
#  31  Recycles oil               0 non-null      object
#  32  Bio fuel                   0 non-null      object
#  33  Electric vehicle charging  0 non-null      object
#  34  Composting sawdust         0 non-null      object
#  35  Recycling center           0 non-null      object
#  36  zip_code                   6591 non-null   object
#  37  State                      8309 non-null   object
#  38  water_binary               8309 non-null   int64
#  39  toilets_binary             8309 non-null   int64
#  40  lat_from_df                8309 non-null   object
#  41  long_from_df               8309 non-null   object
# dtypes: float64(13), int64(2), object(27)
# memory usage: 2.7+ MB

# %%
type(image_file_df.iloc[0,:][4])
# image_file_df['lat_from_file'].unique()
# Out:
# str

# %%
lats = list(image_file_df['lat_from_file'].values)
lats = list(image_file_df['lat_from_file'].to_list)

# %%
lats[0]
# Out:
# array(['38.98102', '38.98102'], dtype=object)

# %%
image_file_df.groupby('lat_from_file').agg({'filename':'count'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-3266e1bb9bc0> in <module>
# ----> 1 image_file_df.groupby('lat_from_file').agg({'filename':'count'})
#
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6518             squeeze=squeeze,
#    6519             observed=observed,
# -> 6520             dropna=dropna,
#    6521         )
#    6522
#
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
#     532                 mutated=self.mutated,
# --> 533                 dropna=self.dropna,
#     534             )
#     535
#
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     807                 dropna=dropna,
#     808             )
# --> 809             if not isinstance(gpr, Grouping)
#     810             else gpr
#     811         )
#
# /usr/local/anaconda3/envs/py377/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis, dropna)
#     515                 if getattr(self.grouper, "ndim", 1) != 1:
#     516                     t = self.name or str(type(self.grouper))
# --> 517                     raise ValueError(f"Grouper for '{t}' not 1-dimensional")
#     518                 self.grouper = self.index.map(self.grouper)
#     519                 if not (
#
# ValueError: Grouper for 'lat_from_file' not 1-dimensional

# %%
All_USdata_est_wild.loc[All_USdata_est_wild['Latitude']==38.46495]
# Out:
#      Location                Name      Category  \
# 9479      NaN  I-5/ fishing place  Wild Camping
#
#                                             Description  Latitude  Longitude  \
# 9479  It’s a large area big enough to park for the n...   38.4650  -121.5031
#
#       Altitude            Date verified Open Electricity Wifi Kitchen  \
# 9479    0.0000  2020-03-08 00:00:00 UTC  Yes          No   No      No
#
#       Parking Restaurant Showers Water Toilets Big rig friendly Tent friendly  \
# 9479      nan    Unknown      No    No      No               No            No
#
#      Pet friendly Sanitation dump station  Outdoor gear  Groceries  \
# 9479          Yes                     NaN           nan        nan
#
#       Artesian goods  Bakery  Rarity in this area  Repairs vehicles  \
# 9479             nan     nan                  nan               nan
#
#       Repairs motorcycles  Repairs bicycles  Sells parts Recycles batteries  \
# 9479                  nan               nan          nan                NaN
#
#      Recycles oil Bio fuel Electric vehicle charging Composting sawdust  \
# 9479          NaN      NaN                       NaN                NaN
#
#      Recycling center zip_code State  water_binary  toilets_binary  \
# 9479              NaN    95832    CA             0               0
#
#      lat_from_df long_from_df
# 9479    38.46495   -121.50308

# %%
image_file_df.iloc[12]
# Out:
# filename          satimg_CA_5739_Wild Camping_17_38.46495_-121.5...
# lat_from_file                                              38.46495
# long_from_file                                           -121.50308
# order                                                            12
# Name: 12, dtype: object

# %%
image_df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-302-b0f5abe4c84d> in <module>
# ----> 1 image_df2
#
# NameError: name 'image_df2' is not defined

# %%
All_USdata_est_wild_no_dup
# Out:
#                                                     Location  \
# 0      Borrego Salton Seaway, Borrego Springs, CA 92004, USA
# 1              Stateline Campground Rd, Kanab, UT 84741, USA
# 2                       Glenn Hwy, Glennallen, AK 99588, USA
# 3           Beverly Beach State Park, Newport, OR 97365, USA
# 4                        Cottell Ln, Coos Bay, OR 97420, USA
# ...                                                      ...
# 12403                    Unnamed Road, Fallon, NV 89406, USA
# 12404              2560 E Lucky Ln, Flagstaff, AZ 86004, USA
# 12408        Mexican Hat Rock Rd, Mexican Hat, UT 84531, USA
# 12403          NaN      NaN                       NaN                NaN
# 12404          NaN      NaN                       NaN                NaN
# 12408          NaN      NaN                       NaN                NaN
# 12409          NaN      NaN                       NaN                NaN
# 12410          NaN      NaN                       NaN                NaN
#
#       Recycling center zip_code State  water_binary  toilets_binary  \
# 0                  NaN      NaN    CA             0               1
# 1                  NaN      NaN    UT             0               1
# 2                  NaN      NaN    AK             0               0
# 3                  NaN      NaN    OR             1               1
# 4                  NaN      NaN    OR             1               1
# ...                ...      ...   ...           ...             ...
# 12403              NaN      NaN    NV             0               1
# 12404              NaN      NaN    AZ             1               0
# 12408              NaN      NaN    UT             0               0
# 12409              NaN      NaN    TX             0               0
# 12410              NaN      NaN    ME             0               0
#
#       lat_from_df long_from_df
# 0       33.280188  -116.145787
# 1       37.001290  -112.035587
# 2       62.095368  -145.980492
# 3       44.728808  -124.055513
# 4       43.330797  -124.370728
# ...           ...          ...
# 12403   39.409003  -118.629126
# 12404   35.195679   -111.61735
# 12408   37.175709   -109.84558
# 12409   29.443920    -98.48244
# 12410   44.345209    -70.14935
#
# [8309 rows x 42 columns]

# %%
All_USdata_est_wild_no_dup2 = All_USdata_est_wild_no_dup.copy()
All_USdata_est_wild_no_dup2['latlong_test'] = All_USdata_est_wild_no_dup2['lat_from_df'].astype('str') + '_' + All_USdata_est_wild_no_dup2['long_from_df'].astype('str')

# %%
image_file_df2 = image_file_df.copy()
image_file_df2['latlong_test'] = image_file_df2['lat_from_file'].astype('str') + '_' + image_file_df2['long_from_file'].astype('str')

# %%
image_file_df3 = image_file_df2.drop(['lat_from_file', 'long_from_file'], axis=1)

# %%
image_file_df3
# Out:
#                                                             filename  order  \
# 0                 satimg_CO__352_Wild Camping_17_38.98102_-107.32651      0
# 1               satimg_ID_7863_Wild Camping_17_43.149667_-111.052531      1
# 2         satimg_TX_6214_Wild Camping_17_35.2375_-102.83496099999999      2
# 3               satimg_CO__216_Wild Camping_17_39.337122_-107.660378      3
# 4      satimg_AZ_6033_Wild Camping_17_34.169239000000005_-110.794278      4
# ...                                                              ...    ...
# 7850  satimg_UT_1580_Established Campground_17_38.482453_-109.741828   7850
# 7851   satimg_FL_3132_Established Campground_17_25.849862_-80.989081   7851
# 7852   satimg_TN_3372_Established Campground_17_35.613972_-88.040368   7852
# 7853    satimg_SD_2626_Established Campground_17_44.361324_-97.13078   7853
# 7854      satimg_TN_1296_Established Campground_17_36.55846_-87.9052   7854
#
#                latlong_test
# 0       38.98102_-107.32651
# 1     43.149667_-111.052531
# 2       35.2375_-102.834960
# 3     39.337122_-107.660378
# 4     34.169239_-110.794278
# ...                     ...
# 7850  38.482453_-109.741828
# 7851   25.849862_-80.989081
# 7852   35.613972_-88.040368
# 7853    44.361324_-97.13078
# 7854      36.55846_-87.9052
#
# [7855 rows x 3 columns]

# %%
All_USdata_est_wild_no_dup2
# Out:
#                                                     Location  \
# 0      Borrego Salton Seaway, Borrego Springs, CA 92004, USA
# 1              Stateline Campground Rd, Kanab, UT 84741, USA
# 12404                  nan               nan          nan                NaN
# 12408                  nan               nan          nan                NaN
# 12409                  nan               nan          nan                NaN
# 12410                  nan               nan          nan                NaN
#
#       Recycles oil Bio fuel Electric vehicle charging Composting sawdust  \
# 0              NaN      NaN                       NaN                NaN
# 1              NaN      NaN                       NaN                NaN
# 2              NaN      NaN                       NaN                NaN
# 3              NaN      NaN                       NaN                NaN
# 4              NaN      NaN                       NaN                NaN
# ...            ...      ...                       ...                ...
# 12403          NaN      NaN                       NaN                NaN
# 12404          NaN      NaN                       NaN                NaN
# 12408          NaN      NaN                       NaN                NaN
# 12409          NaN      NaN                       NaN                NaN
# 12410          NaN      NaN                       NaN                NaN
#
#       Recycling center zip_code State  water_binary  toilets_binary  \
# 0                  NaN      NaN    CA             0               1
# 1                  NaN      NaN    UT             0               1
# 2                  NaN      NaN    AK             0               0
# 3                  NaN      NaN    OR             1               1
# 4                  NaN      NaN    OR             1               1
# ...                ...      ...   ...           ...             ...
# 12403              NaN      NaN    NV             0               1
# 12404              NaN      NaN    AZ             1               0
# 12408              NaN      NaN    UT             0               0
# 12409              NaN      NaN    TX             0               0
# 12410              NaN      NaN    ME             0               0
#
#       lat_from_df long_from_df           latlong_test
# 0       33.280188  -116.145787  33.280188_-116.145787
# 1       37.001290  -112.035587  37.001290_-112.035587
# 2       62.095368  -145.980492  62.095368_-145.980492
# 3       44.728808  -124.055513  44.728808_-124.055513
# 4       43.330797  -124.370728  43.330797_-124.370728
# ...           ...          ...                    ...
# 12403   39.409003  -118.629126  39.409003_-118.629126
# 12404   35.195679   -111.61735   35.195679_-111.61735
# 12408   37.175709   -109.84558   37.175709_-109.84558
# 12409   29.443920    -98.48244    29.443920_-98.48244
# 12410   44.345209    -70.14935    44.345209_-70.14935
#
# [8309 rows x 43 columns]

# %%
# join with df of data, keep all images, hopefully they have data in the df
image_file_df_final_with_df = image_file_df3.merge(All_USdata_est_wild_no_dup2, how='outer', 
                                                  on = 'latlong_test')

# %%
# join with df of data, keep all images, hopefully they have data in the df
image_file_df_final_with_df = image_file_df.merge(All_USdata_est_wild_no_dup, how='outer', 
                                                  left_on=['lat_from_file', 'long_from_file'],
                                                 right_on=['lat_from_df', 'long_from_df'])

# %%
image_file_df_final_with_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9632 entries, 0 to 9631
# Data columns (total 45 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   filename                   7855 non-null   object
#  1   order                      7855 non-null   float64
#  2   latlong_test               9632 non-null   object
#  3   Location                   1718 non-null   object
#  4   Name                       8313 non-null   object
#  5   Category                   8313 non-null   object
#  6   Description                8312 non-null   object
#  7   Latitude                   8313 non-null   float64
#  8   Longitude                  8313 non-null   float64
#  9   Altitude                   8099 non-null   float64
#  10  Date verified              8313 non-null   object
#  11  Open                       8313 non-null   object
#  12  Electricity                8313 non-null   object
#  13  Wifi                       8313 non-null   object
#  14  Kitchen                    8313 non-null   object
#  15  Parking                    0 non-null      float64
#  16  Restaurant                 8313 non-null   object
#  17  Showers                    8313 non-null   object
#  18  Water                      8313 non-null   object
#  19  Toilets                    8313 non-null   object
#  20  Big rig friendly           8313 non-null   object
#  21  Tent friendly              8313 non-null   object
#  22  Pet friendly               8313 non-null   object
#  23  Sanitation dump station    3706 non-null   object
#  24  Outdoor gear               0 non-null      float64
#  25  Groceries                  0 non-null      float64
#  26  Artesian goods             0 non-null      float64
#  27  Bakery                     0 non-null      float64
#  28  Rarity in this area        0 non-null      float64
#  29  Repairs vehicles           0 non-null      float64
#  30  Repairs motorcycles        0 non-null      float64
#  31  Repairs bicycles           0 non-null      float64
#  32  Sells parts                0 non-null      float64
#  33  Recycles batteries         0 non-null      object
#  34  Recycles oil               0 non-null      object
#  35  Bio fuel                   0 non-null      object
#  36  Electric vehicle charging  0 non-null      object
#  37  Composting sawdust         0 non-null      object
#  38  Recycling center           0 non-null      object
#  39  zip_code                   6595 non-null   object
#  40  State                      8313 non-null   object
#  41  water_binary               8313 non-null   float64
#  42  toilets_binary             8313 non-null   float64
#  43  lat_from_df                8313 non-null   object
#  44  long_from_df               8313 non-null   object
# dtypes: float64(16), object(29)
# memory usage: 3.4+ MB

# %%
image_file_df_final_with_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9632 entries, 0 to 9631
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   filename                   7855 non-null   object
#  1   lat_from_file              7855 non-null   object
#  2   long_from_file             7855 non-null   object
#  3   order                      7855 non-null   float64
#  4   Location                   1718 non-null   object
#  5   Name                       8313 non-null   object
#  6   Category                   8313 non-null   object
#  7   Description                8312 non-null   object
#  8   Latitude                   8313 non-null   float64
#  9   Longitude                  8313 non-null   float64
#  10  Altitude                   8099 non-null   float64
#  11  Date verified              8313 non-null   object
#  12  Open                       8313 non-null   object
#  13  Electricity                8313 non-null   object
#  14  Wifi                       8313 non-null   object
#  15  Kitchen                    8313 non-null   object
#  16  Parking                    0 non-null      float64
#  17  Restaurant                 8313 non-null   object
#  18  Showers                    8313 non-null   object
#  19  Water                      8313 non-null   object
#  20  Toilets                    8313 non-null   object
#  21  Big rig friendly           8313 non-null   object
#  22  Tent friendly              8313 non-null   object
#  23  Pet friendly               8313 non-null   object
#  24  Sanitation dump station    3706 non-null   object
#  25  Outdoor gear               0 non-null      float64
#  26  Groceries                  0 non-null      float64
#  27  Artesian goods             0 non-null      float64
#  28  Bakery                     0 non-null      float64
#  29  Rarity in this area        0 non-null      float64
#  30  Repairs vehicles           0 non-null      float64
#  31  Repairs motorcycles        0 non-null      float64
#  32  Repairs bicycles           0 non-null      float64
#  33  Sells parts                0 non-null      float64
#  34  Recycles batteries         0 non-null      object
#  35  Recycles oil               0 non-null      object
#  36  Bio fuel                   0 non-null      object
#  37  Electric vehicle charging  0 non-null      object
#  38  Composting sawdust         0 non-null      object
#  39  Recycling center           0 non-null      object
#  40  zip_code                   6595 non-null   object
#  41  State                      8313 non-null   object
#  42  water_binary               8313 non-null   float64
#  43  toilets_binary             8313 non-null   float64
#  44  lat_from_df                8313 non-null   object
#  45  long_from_df               8313 non-null   object
# dtypes: float64(16), object(30)
# memory usage: 3.5+ MB

# %%
image_file_df_final_with_df.to_csv('../data/again.csv')
